# %%
# !pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 66.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 37.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 116.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 26.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 18.9 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix, classification_report
import pandas as pd
import numpy as np
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix
from simpletransformers.classification import ClassificationModel

# %%
# Carregar os dados de treino e teste
arquivo_csv_teste ='/content/teste_ironias_reduzido.csv'
arquivo_csv_treino = '/content/train_tweets.csv'

# %%
dados_treino = pd.read_csv(arquivo_csv_treino, sep='\t', lineterminator='\n')
dados_teste = pd.read_csv(arquivo_csv_teste, sep='\t', lineterminator='\n')

# %%
dados_teste
# Out:
#       Unnamed: 0                                               text  \
# 0              0  Aquele momento que o gato preto volta pra não ...
# 1              1  Marcelo Oliveira pode estar poupando Matheus S...
# 2              2  ECONOMIAALERTANÃO! QUEIRAM ASSISTIR O MAIOR ES...
# 3              3      São Paulo caindo de pé como um bom perdedor.
# 4              4                                  claro que foi....
# ...          ...                                                ...
# 1495        1495  interessante perceber como o catedrático vai d...
# 1496        1496                             So notícia boa! Uhuuu
# 1497        1497  AGORA VAI! Realmente bater em jogador resolve ...
# 1498        1498  Economia.Presidente do Senado admite possibili...
# 1499        1499  Assistindo a Copa do Nordeste e por ironia o E...
#
#       prediction
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1
# ...          ...
# 1495           1
# ...

# %%
train_df = pd.DataFrame({'text': dados_treino.iloc[:, 0], 'labels': dados_treino.iloc[:, 1]})

# %%
train_df
# Out:
#                                                     text  labels
# 0      Tem coisas bem mais importantes acontecendo em...       1
# 1      Quando a vida me desafia, eu coloco meu colete...       1
# 2                                    Agora vai, hein!?         1
# 3                                E o fim do mundo?? kkk'       1
# 4      Como que tua ex-chefe te manda mensagem dizend...       1
# ...                                                  ...     ...
# 12165  Vem fazer economia no Carnaúba! Oferta válida ...       0
# 12166  Refis: Meirelles fecha acordo com deputadospor...       0
# 12167  Internet da  é perfeita, n cai, n fica lenta e...       1
# 12168  Realmente foi FHC política brasil fhc  planore...       1
# 12169  Morri agora... tipo issoÉ a crise :-Pinstagood...       1
#
# [12170 rows x 2 columns]

# %%
# Criar o modelo de classificação
model_args = {
    'num_train_epochs': 10,
    'train_batch_size': 8,
    'eval_batch_size': 8,
    'overwrite_output_dir': True,
    'save_steps': -1,
    'save_model_every_epoch': False,
    'learning_rate': 3e-5,
    'fp16': True,
}

# %%
model = ClassificationModel(
    'bert',
    #'neuralmind/bert-base-portuguese-cased',
    'neuralmind/bert-large-portuguese-cased',
    num_labels=2,
    args=model_args,
    use_cuda=True,  # Se estiver usando uma GPU, você pode mudar para True
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at neuralmind/bert-large-portuguese-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Treinar o modelo nos dados de treino
model.train_model(train_df)
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ...
# Running Epoch 10 of 10:   0%|          | 0/1522 [00:00<?, ?it/s]
# (15220, 0.01635854470099319)

# %%
eval_df = pd.DataFrame({'text': dados_teste.iloc[:, 1], 'labels': dados_teste.iloc[:, 2]})

# %%
eval_df
# Out:
#                                                    text  labels
# 0     Aquele momento que o gato preto volta pra não ...       1
# 1     Marcelo Oliveira pode estar poupando Matheus S...       1
# 2     ECONOMIAALERTANÃO! QUEIRAM ASSISTIR O MAIOR ES...       0
# 3         São Paulo caindo de pé como um bom perdedor.        1
# 4                                     claro que foi....       1
# ...                                                 ...     ...
# 1495  interessante perceber como o catedrático vai d...       1
# 1496                             So notícia boa! Uhuuu        1
# 1497  AGORA VAI! Realmente bater em jogador resolve ...       1
# 1498  Economia.Presidente do Senado admite possibili...       0
# 1499  Assistindo a Copa do Nordeste e por ironia o E...       1
#
# [1500 rows x 2 columns]

# %%
predictions, raw_outputs = model.predict(eval_df['text'].tolist())
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ...
#   0%|          | 0/188 [00:00<?, ?it/s]

# %%
probabilities = np.exp(raw_outputs) / np.sum(np.exp(raw_outputs), axis=1, keepdims=True)
predicted_probs = probabilities[:, 1]  # Probabilidades para a classe 1 (ironia)

# %%
eval_df['predictions'] = predictions
eval_df['probabilities'] = predicted_probs

# %%
eval_df
# Out:
#                                                    text  labels  predictions  \
# 0     Aquele momento que o gato preto volta pra não ...       1            1
# 1     Marcelo Oliveira pode estar poupando Matheus S...       1            1
# 2     ECONOMIAALERTANÃO! QUEIRAM ASSISTIR O MAIOR ES...       0            0
# 3         São Paulo caindo de pé como um bom perdedor.        1            1
# 4                                     claro que foi....       1            1
# ...                                                 ...     ...          ...
# 1495  interessante perceber como o catedrático vai d...       1            1
# 1496                             So notícia boa! Uhuuu        1            1
# 1497  AGORA VAI! Realmente bater em jogador resolve ...       1            1
# 1498  Economia.Presidente do Senado admite possibili...       0            0
# 1499  Assistindo a Copa do Nordeste e por ironia o E...       1            1
#
#       probabilities
# 0          0.999999
# ...

# %%
eval_df.to_csv('/content/results_final_data.csv', index=False)

# %%
train_df
# Out:
#                                                     text  labels
# 0      Tem coisas bem mais importantes acontecendo em...       1
# 1      Quando a vida me desafia, eu coloco meu colete...       1
# 2                                    Agora vai, hein!?         1
# 3                                E o fim do mundo?? kkk'       1
# 4      Como que tua ex-chefe te manda mensagem dizend...       1
# ...                                                  ...     ...
# 12165  Vem fazer economia no Carnaúba! Oferta válida ...       0
# 12166  Refis: Meirelles fecha acordo com deputadospor...       0
# 12167  Internet da  é perfeita, n cai, n fica lenta e...       1
# 12168  Realmente foi FHC política brasil fhc  planore...       1
# 12169  Morri agora... tipo issoÉ a crise :-Pinstagood...       1
#
# [12170 rows x 2 columns]

# %%
train_df[train_df.text.isin(eval_df.text)]
# Out:
# Empty DataFrame
# Columns: [text, labels]
# Index: []

# %%
eval_df[eval_df.text.isin(train_df.text)]
# Out:
# Empty DataFrame
# Columns: [text, labels, predictions, probabilities]
# Index: []
